# %%
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import (train_test_split, KFold, cross_val_score, 
GridSearchCV, StratifiedKFold)
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings("ignore")
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Predicciones

# %% [markdown]
# Este notebook es el que sera entregado a la persona tecnica del banco que se encaragara de revisarlo de manera minuciosa y a nivel muy tecnico. A continuacion se presenta un bosquejo de las secciones que debe contener.
# Puedes agregar tantas celdas como requieras, pero manten la estructura general del proyecto.

# %% [markdown]
# Deberas utilizar `autogluon` para realizar el proyecto, sin embargo debes de ser mas cuidadosx en la seleccion de variables que lo que fuimos en el automl, puedes usar las variables que utilizamos en las predicciones de `sklearn`.

# %% [markdown]
# Pon especial atencion en tus sets, recuerda que debes entrenar el modelo, ver la calibracion, sugerir tasas de interes y simular como se va a comportar en la realidad. Por ende, debes de ser extremadamente cuidadosx en como los separas. Una mala separacion de estos sets arruinaria todo el proyecto, pues seria inutil.

# %% [markdown]
# ## ETL

# %% [markdown]
# En esta seccion deberas cargas los datos desde el github de Lending Club

# %%
loans = pd.read_parquet('loans_sampe_data.parquet')
metadata = pd.read_excel('https://resources.lendingclub.com/LCDataDictionary.xlsx')
metadata.columns = ['feature', 'description']
loans['loan_status'].value_counts(dropna=False)
# Out:
# loan_status
# Fully Paid            69982
# Charged Off           16156
# Current               12726
# Late (31-120 days)      730
# In Grace Period         264
# Late (16-30 days)       139
# Default                   3
# Name: count, dtype: int64

# %%
df = loans.loc[loans['loan_status'].isin(['Fully Paid', 
                                                   'Charged Off'])]
df['loan_status'].value_counts(normalize=True, dropna=False)
# Out:
# loan_status
# Fully Paid     0.812441
# Charged Off    0.187559
# Name: proportion, dtype: float64

# %%
df['charged_off'] = (df['loan_status'] == 'Charged Off').apply(np.uint8)
df.drop('loan_status', axis=1, inplace=True)
df['charged_off'].unique()
# Out:
# array([0, 1], dtype=uint8)

# %% [markdown]
# ## Feature Selection

# %%
elegidas = ['charged_off','funded_amnt','addr_state', 'annual_inc',
            'application_type', 'dti', 'earliest_cr_line', 'emp_length', 
            'emp_title', 'fico_range_high', 'fico_range_low', 'grade',
            'home_ownership', 'initial_list_status', 'installment', 
            'loan_amnt', 'loan_status', 'mort_acc', 
            'open_acc', 'pub_rec', 'pub_rec_bankruptcies', 'purpose', 
            'revol_bal', 'revol_util', 'sub_grade', 'term', 'title', 
            'total_acc', 'verification_status', 'last_pymnt_amnt','num_actv_rev_tl', 'mo_sin_rcnt_rev_tl_op',
            'mo_sin_old_rev_tl_op',"bc_util","bc_open_to_buy","avg_cur_bal",
            "acc_open_past_24mths" ]
len(elegidas)
# Out:
# 37

# %%
drop_no_intuitivas = [col for col in df.columns if col not in elegidas]
df.drop(labels=drop_no_intuitivas , axis=1, inplace=True)
df
# Out:
#        loan_amnt  funded_amnt        term  installment grade sub_grade  \
# 0        15000.0      15000.0   60 months       336.64     C        C1
# 1        10400.0      10400.0   36 months       321.08     A        A3
# 2        21425.0      21425.0   60 months       516.36     D        D1
# 4         7650.0       7650.0   36 months       260.20     C        C3
# 5         9600.0       9600.0   36 months       326.53     C        C3
# ...          ...          ...         ...          ...   ...       ...
# 99994    15000.0      15000.0   36 months       485.07     B        B2
# 99995     8400.0       8400.0   36 months       267.79     B        B1
# 99996    10000.0      10000.0   36 months       336.90     C        C1
# 99998     8475.0       8475.0   36 months       336.92     F        F4
# 99999    25000.0      25000.0   36 months       808.45     B        B2
#
#                                       emp_title emp_length home_ownership  \
# 0                                    MANAGEMENT  10+ years           RENT
# 1                Truck Driver Delivery Personel    8 years       MORTGAGE
# 2               Programming Analysis Supervisor    6 years           RENT
# 4                          Technical Specialist   < 1 year           RENT
# 5                              Admin Specialist  10+ years           RENT
# ...                                         ...        ...            ...
# 99994  Senior Clinical Business Solutions Analy  10+ years       MORTGAGE
# 99995                         Software Engineer    2 years       MORTGAGE
# 99996            Assistant Professor of English    3 years           RENT
# 99998                  Records Examiner Analyst  10+ years           RENT
# 99999             Occupational Theapy Assistant    3 years            OWN
#
#        annual_inc  ... acc_open_past_24mths avg_cur_bal bc_open_to_buy  \
# 0         78000.0  ...                  5.0     29828.0         9525.0
# 1         58000.0  ...                  7.0      9536.0         7599.0
# 2         63800.0  ...                  4.0      4232.0          324.0
# 4         50000.0  ...                  6.0      5857.0          332.0
# 5         69000.0  ...                  8.0      3214.0         6494.0
# ...           ...  ...                  ...         ...            ...
# 99994     84136.0  ...                  5.0     14311.0        28091.0
# 99995     91000.0  ...                  2.0     25364.0         2505.0
# 99996     53133.0  ...                  3.0      4219.0        13974.0
# 99998     52000.0  ...                  8.0      3125.0          324.0
# 99999     60000.0  ...                  5.0     10133.0        17153.0
#
#       bc_util  mo_sin_old_rev_tl_op mo_sin_rcnt_rev_tl_op  mort_acc  \
# 0         4.7                 244.0                   1.0       0.0
# 1        41.5                 290.0                   1.0       1.0
# 2        97.8                 136.0                   7.0       0.0
# 4        93.2                 148.0                   8.0       0.0
# 5        69.2                 265.0                  23.0       0.0
# ...       ...                   ...                   ...       ...
# 99994    31.3                 356.0                   3.0       5.0
# 99995    77.2                 287.0                   5.0       1.0
# 99996    42.5                 158.0                   5.0       0.0
# 99998    88.0                 164.0                   7.0       0.0
# 99999    57.4                 180.0                   1.0       2.0
#
#        num_actv_rev_tl  pub_rec_bankruptcies  charged_off
# 0                  4.0                   0.0            0
# 1                  9.0                   0.0            1
# 2                  4.0                   0.0            0
# 4                  4.0                   0.0            1
# 5                  7.0                   0.0            0
# ...                ...                   ...          ...
# 99994              5.0                   0.0            0
# 99995              2.0                   0.0            0
# 99996              5.0                   0.0            0
# 99998              3.0                   1.0            1
# 99999              7.0                   0.0            0
#
# [86138 rows x 36 columns]

# %% [markdown]
# ## Feature selection and feature engineering

# %%
def _check_type(value):
    ''' 
    Infiere si la variable es categorica o numerica
    apartir del tipo
    '''
    if value==object:
        return 'categorica'
    elif value==bool:
        return 'categorica' 
    elif value=='int64':
        return 'numerica'
    elif value=='float64':
        return 'numerica'
    
feature_type = pd.DataFrame(df.dtypes)
feature_type[0] = feature_type[0].apply(lambda x: _check_type(x))
feature_type.reset_index(inplace=True)
feature_type.rename(columns={'index':'feature',0:'tipo'},inplace=True)

features_cat = feature_type[feature_type['tipo']=='categorica']['feature']
features_cat = list(features_cat)
features_cat
# Out:
# ['term',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'verification_status',
#  'purpose',
#  'title',
#  'addr_state',
#  'earliest_cr_line',
#  'initial_list_status',
#  'application_type']

# %%
cat_not_inclue = ['emp_title', 'application_type',
              'title', 'addr_state', 'pub_rec', 'revol_bal',
              'total_acc', 'pub_rec_bankruptcies']
features_cat = [f for f in features_cat if f not in cat_not_inclue]
df.drop(cat_not_inclue, axis=1, inplace=True)
df[features_cat] = df[features_cat].fillna('nan-missing')
df
# Out:
#        loan_amnt  funded_amnt        term  installment grade sub_grade  \
# 0        15000.0      15000.0   60 months       336.64     C        C1
# 1        10400.0      10400.0   36 months       321.08     A        A3
# 2        21425.0      21425.0   60 months       516.36     D        D1
# 4         7650.0       7650.0   36 months       260.20     C        C3
# 5         9600.0       9600.0   36 months       326.53     C        C3
# ...          ...          ...         ...          ...   ...       ...
# 99994    15000.0      15000.0   36 months       485.07     B        B2
# 99995     8400.0       8400.0   36 months       267.79     B        B1
# 99996    10000.0      10000.0   36 months       336.90     C        C1
# 99998     8475.0       8475.0   36 months       336.92     F        F4
# 99999    25000.0      25000.0   36 months       808.45     B        B2
#
#       emp_length home_ownership  annual_inc verification_status  ...  \
# 0      10+ years           RENT     78000.0     Source Verified  ...
# 1        8 years       MORTGAGE     58000.0        Not Verified  ...
# 2        6 years           RENT     63800.0     Source Verified  ...
# 4       < 1 year           RENT     50000.0     Source Verified  ...
# 5      10+ years           RENT     69000.0     Source Verified  ...
# ...          ...            ...         ...                 ...  ...
# 99994  10+ years       MORTGAGE     84136.0        Not Verified  ...
# 99995    2 years       MORTGAGE     91000.0     Source Verified  ...
# 99996    3 years           RENT     53133.0        Not Verified  ...
# 99998  10+ years           RENT     52000.0            Verified  ...
# 99999    3 years            OWN     60000.0     Source Verified  ...
#
#       last_pymnt_amnt  acc_open_past_24mths avg_cur_bal  bc_open_to_buy  \
# 0            12017.81                   5.0     29828.0          9525.0
# 1              321.08                   7.0      9536.0          7599.0
# 2            17813.19                   4.0      4232.0           324.0
# 4               17.70                   6.0      5857.0           332.0
# 5             9338.58                   8.0      3214.0          6494.0
# ...               ...                   ...         ...             ...
# 99994        10584.91                   5.0     14311.0         28091.0
# 99995          267.50                   2.0     25364.0          2505.0
# 99996         5594.78                   3.0      4219.0         13974.0
# 99998          336.92                   8.0      3125.0           324.0
# 99999         4759.78                   5.0     10133.0         17153.0
#
#        bc_util  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op mort_acc  \
# 0          4.7                 244.0                    1.0      0.0
# 1         41.5                 290.0                    1.0      1.0
# 2         97.8                 136.0                    7.0      0.0
# 4         93.2                 148.0                    8.0      0.0
# 5         69.2                 265.0                   23.0      0.0
# ...        ...                   ...                    ...      ...
# 99994     31.3                 356.0                    3.0      5.0
# 99995     77.2                 287.0                    5.0      1.0
# 99996     42.5                 158.0                    5.0      0.0
# 99998     88.0                 164.0                    7.0      0.0
# 99999     57.4                 180.0                    1.0      2.0
#
#        num_actv_rev_tl  charged_off
# 0                  4.0            0
# 1                  9.0            1
# 2                  4.0            0
# 4                  4.0            1
# 5                  7.0            0
# ...                ...          ...
# 99994              5.0            0
# 99995              2.0            0
# 99996              5.0            0
# 99998              3.0            1
# 99999              7.0            0
#
# [86138 rows x 28 columns]

# %%
df['term'] = df['term'].apply(lambda s: np.int8(s.split()[0]))

df.drop(['emp_length'], axis=1, inplace=True)

label_f = LabelEncoder()
lf = df['sub_grade'].apply(str).unique()
lf[-1] = 'missing-nan'
label_f.fit(lf)
df['sub_grade'] = label_f.fit_transform(df['sub_grade'])

df.drop(['grade'], axis=1, inplace=True)

df = df[df['home_ownership']!='ANY']

# %%
enc = OneHotEncoder(handle_unknown='ignore', sparse=False)
a = enc.fit_transform(X=df[['home_ownership']])
a = pd.DataFrame(a)
a.columns = enc.get_feature_names_out()
df[a.columns] = a.values
df.drop(columns=['home_ownership_OWN', 'home_ownership'], inplace=True)

# %%
enc = OneHotEncoder(handle_unknown='ignore', sparse=False)
a = enc.fit_transform(X=df[['verification_status']])
a = pd.DataFrame(a)
a.columns = enc.get_feature_names_out()
df[a.columns] = a.values
df.drop(columns=['verification_status'], inplace=True)

# %%
dummies_purpose = pd.get_dummies(df[['purpose', 'charged_off']], columns=['purpose'], 
               drop_first=True).corr().index
dummies_purpose = [v for v in dummies_purpose if v not in ['charged_off', 
                                                           'purpose_credit_card',
                                                           'purpose_debt_consolidation'
                                                           ]]
dummies_purpose = [v.replace('purpose_','') for v in dummies_purpose]                                                           

enc_p = OneHotEncoder(handle_unknown='ignore', sparse=False)
enc_p.fit(X=df[['purpose']])
a = enc_p.transform(X=df[['purpose']])
a = pd.DataFrame(a)
a.columns = enc_p.get_feature_names_out()
df[a.columns] = a.values

dummies_purpose = [f'purpose_{v}' for v in dummies_purpose]

df.drop(columns=dummies_purpose + ['purpose'], inplace=True)

# %%
df['earliest_cr_line'] = df['earliest_cr_line'].apply(lambda x: float(x[4:]))
df.drop(columns=['initial_list_status'], inplace=True)

# %%
feature_correlation = df.loc[:, df.columns != 'charged_off'].corr()
upper = feature_correlation.where(np.triu(np.ones(
    feature_correlation.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.9)]
df.drop(to_drop, axis=1, inplace=True)

# %%
columns_order = [col for col in df.columns if col != 'charged_off'] + ['charged_off']
df = df[columns_order]

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
df = pd.DataFrame(imp_mean.fit_transform(df), columns=df.columns)

df = pd.DataFrame(imp_mean.fit_transform(df), columns=df.columns)

# %%
df.rename(columns={'charged_off':'y'}, inplace=True)

# Assuming 'charged_off' is your target variable
X = df.drop('y', axis=1)  # Features
y = df['y']  # Target variable

# Split the data into train and test sets, stratified on 'charged_off'
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Check the proportions in train and test sets
train_proportions = y_train.value_counts(normalize=True)
test_proportions = y_test.value_counts(normalize=True)

print("Train set proportions:")
print(train_proportions)

print("\nTest set proportions:")
print(test_proportions)
# Out:
# Train set proportions:
# y
# 0.0    0.812434
# 1.0    0.187566
# Name: proportion, dtype: float64
#
# Test set proportions:
# y
# 0.0    0.812456
# 1.0    0.187544
# Name: proportion, dtype: float64

# %% [markdown]
# ## Entrenamiento

# %% [markdown]
# Codigo de entrenamiento de modelos con `autogluon`. Toma en cuenta el imbalance de clases y las peticiones que tiene el banco.

# %%
from autogluon.tabular import TabularPredictor

# %%
train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

train_df.to_parquet('train_df.parquet')
test_df.to_parquet('test_df.parquet')

# %%
label = 'y'
predictor = TabularPredictor(label=label, path='agModels')  # 'agModels' is the folder where models and intermediate data will be saved
predictor.fit(train_data=train_df, presets='best_quality', auto_stack=True)
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: agModels/ds_sub_fit/sub_fit_ho.
# 2024-04-14 21:07:49,058	INFO util.py:159 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# Beginning AutoGluon training ... Time limit = 900s
# AutoGluon will save models to "agModels/ds_sub_fit/sub_fit_ho"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 22.6.0: Mon Feb 19 19:48:53 PST 2024; root:xnu-8796.141.3.704.6~1/RELEASE_X86_64
# CPU Count:          4
# Memory Avail:       2.19 GB / 8.00 GB (27.4%)
# Disk Space Avail:   12.17 GB / 112.71 GB (10.8%)
# ===================================================
# Train Data Rows:    61252
# Train Data Columns: 26
# Label Column:       y
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2232.24 MB
# 	Train Data (Original)  Memory Usage: 12.15 MB (0.5% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 9 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 26 | ['loan_amnt', 'term', 'sub_grade', 'annual_inc', 'dti', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 17 | ['loan_amnt', 'sub_grade', 'annual_inc', 'dti', 'earliest_cr_line', ...]
# 		('int', ['bool']) :  9 | ['term', 'home_ownership_MORTGAGE', 'home_ownership_RENT', 'verification_status_Not Verified', 'verification_status_Source Verified', ...]
# 	0.2s = Fit runtime
# 	26 features in original data used to generate 26 features in processed data.
# 	Train Data (Processed) Memory Usage: 8.47 MB (0.4% of available memory)
# Data preprocessing and feature engineering runtime = 0.29s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 599.65s of the 899.69s of remaining time.
# 	0.7976	 = Validation score   (accuracy)
# 	0.09s	 = Training   runtime
# 	10.2s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 586.53s of the 886.56s of remaining time.
# 	0.7963	 = Validation score   (accuracy)
# 	0.07s	 = Training   runtime
# 	11.46s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 574.57s of the 874.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.70%)
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=38367, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 226, in <module>
#     _LIB = _load_lib()
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 211, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 452, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=38367, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/common/utils/try_import.py", line 86, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 561.36s of the 861.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.86%)
# 2024-04-14 21:08:32,852	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=38368, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 226, in <module>
#     _LIB = _load_lib()
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 211, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 452, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=38368, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/common/utils/try_import.py", line 86, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# 2024-04-14 21:08:32,855	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-14 21:08:32,859	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=38439, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 226, in <module>
#     _LIB = _load_lib()
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 211, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 452, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=38439, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/common/utils/try_import.py", line 86, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 554.11s of the 854.15s of remaining time.
# 2024-04-14 21:08:40,865	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-14 21:08:40,870	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-14 21:08:40,871	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.8872	 = Validation score   (accuracy)
# 	29.16s	 = Training   runtime
# 	2.58s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 520.43s of the 820.46s of remaining time.
# 	0.8884	 = Validation score   (accuracy)
# 	28.6s	 = Training   runtime
# 	2.46s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 487.78s of the 787.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=3.01%)
# 	0.8929	 = Validation score   (accuracy)
# 	41.59s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 441.84s of the 741.87s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 228 due to low memory. Expected memory usage reduced from 19.71% -> 15.0% of available memory...
# 	0.8812	 = Validation score   (accuracy)
# 	7.46s	 = Training   runtime
# 	2.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 429.82s of the 729.86s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 251 due to low memory. Expected memory usage reduced from 17.9% -> 15.0% of available memory...
# 	0.881	 = Validation score   (accuracy)
# 	9.36s	 = Training   runtime
# 	2.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 415.39s of the 715.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.25%)
# 	0.8923	 = Validation score   (accuracy)
# 	279.03s	 = Training   runtime
# 	2.3s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 129.4s of the 429.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=3.49%)
# 	0.8941	 = Validation score   (accuracy)
# 	22.77s	 = Training   runtime
# 	0.96s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 97.58s of the 397.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.03%)
# 	0.8922	 = Validation score   (accuracy)
# 	93.87s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 296.32s of remaining time.
# 	Ensemble Weights: {'XGBoost_BAG_L1': 0.966, 'CatBoost_BAG_L1': 0.011, 'NeuralNetFastAI_BAG_L1': 0.011, 'NeuralNetTorch_BAG_L1': 0.011}
# 	0.8942	 = Validation score   (accuracy)
# 	19.66s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 276.52s of the 276.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.99%)
# 	Warning: Exception caused LightGBMXT_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=41289, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 226, in <module>
#     _LIB = _load_lib()
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 211, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 452, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=41289, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/common/utils/try_import.py", line 86, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 269.35s of the 269.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=3.13%)
# 2024-04-14 21:18:25,638	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-14 21:18:25,641	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-14 21:18:25,642	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Warning: Exception caused LightGBM_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=41325, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 226, in <module>
#     _LIB = _load_lib()
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/basic.py", line 211, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 452, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/ctypes/__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=41325, ip=127.0.0.1)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/autogluon/common/utils/try_import.py", line 86, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/elcachorrohumano/anaconda3/envs/automl_env/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 262.11s of the 261.99s of remaining time.
# 2024-04-14 21:18:32,646	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-14 21:18:32,648	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-04-14 21:18:32,649	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.8927	 = Validation score   (accuracy)
# 	44.24s	 = Training   runtime
# 	2.83s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 213.57s of the 213.46s of remaining time.
# 	0.8922	 = Validation score   (accuracy)
# 	45.76s	 = Training   runtime
# 	2.86s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 163.44s of the 163.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=3.62%)
# 	0.8945	 = Validation score   (accuracy)
# 	26.79s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 131.34s of the 131.23s of remaining time.
# 	0.8916	 = Validation score   (accuracy)
# 	13.09s	 = Training   runtime
# 	3.0s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 112.65s of the 112.54s of remaining time.
# 	0.8916	 = Validation score   (accuracy)
# 	9.82s	 = Training   runtime
# 	3.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 96.93s of the 96.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.00%)
# 	0.8937	 = Validation score   (accuracy)
# 	95.94s	 = Training   runtime
# 	3.5s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -7.49s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 0.935, 'RandomForestEntr_BAG_L2': 0.022, 'NeuralNetFastAI_BAG_L2': 0.022, 'CatBoost_BAG_L1': 0.011, 'NeuralNetTorch_BAG_L1': 0.011}
# 	0.8946	 = Validation score   (accuracy)
# 	33.69s	 = Training   runtime
# 	0.13s	 = Validation runtime
# AutoGluon training complete, total runtime = 941.39s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels/ds_sub_fit/sub_fit_ho")

# %%
predictor = TabularPredictor.load('agModels/ds_sub_fit/sub_fit_ho')

leaderboard = predictor.leaderboard(test_df, extra_metrics=['mcc', 'balanced_accuracy', 'f1', 'precision', 'roc_auc'])

leaderboard

# %% [markdown]
# ## Seleccion de Modelos

# %% [markdown]
# En esta seccion debes elegir un modelo apra cada caso, y explicar cuidadosamente por que elegiste cada modelo, ademas de indicar que metricas utilizaste para elegir.

# %% [markdown]
# Pon especial atencio a las metricas que elegiste, y justifica por que estas metricas son importantes/buenas para el problema. Recuerda que este notebook sera revisado por una persona tecnica.

# %% [markdown]
# Incluye graficas, tablas o representacions visuales para explicar por que elgiste cada modelo y las metricas que utilizaste para elegir el modelo.

# %% [markdown]
# Salva tus modelos, pues los utilizaras en el siguiente notebook. Para salvar el modelo utiliza la funcion https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.clone_for_deployment.html

# %% [markdown]
# ### Modelo Interpretable

# %% [markdown]
# #### Calibracion del modelo

# %% [markdown]
# En esta seccion revisa la calibracion de tu modelo, recuerda que deberas elegir una tasa de interes, por lo que es importante que tu modelo este calibrado, de no estarlo busca como podrias calibrarlo, o justifica por que no lo calibras y como afectaria los resultados

# %% [markdown]
# ### Modelo no Interpretable

# %% [markdown]
# #### Calibracion del modelo

# %% [markdown]
# En esta seccion revisa la calibracion de tu modelo, recuerda que deberas elegir una tasa de interes, por lo que es importante que tu modelo este calibrado, de no estarlo busca como podrias calibrarlo, o justifica por que no lo calibras y como afectaria los resultados

# %% [markdown]
# ## Explicacion de Variables

# %% [markdown]
# Realiza una explicacion de que variables son importantes, y como podria utilizarlas el banca para explicar a la comision bancaria y regulatoria por que se otorgo o no el prestamo. Pon atencion a que set usaras para esta parte (train, val, test, calibracion, otro?)
